# %%
import numpy as np
import pandas as pd

# %%
state0 = pd.read_csv('states0.csv')
state1 = pd.read_csv('states1.csv')
state2 = pd.read_csv('states2.csv')
state3 = pd.read_csv('states3.csv')
state4 = pd.read_csv('states4.csv')
state5 = pd.read_csv('states5.csv')
state6 = pd.read_csv('states6.csv')
state7 = pd.read_csv('states7.csv')
state8 = pd.read_csv('states8.csv')
state9 = pd.read_csv('states9.csv')

# %%
display(state3)
display(state5)
display(state6)
# Out:
#    Unnamed: 0      State  TotalPop             Hispanic                White  \
# 0           0       Iowa   3093526    5.30364520048603%   87.71968408262464%
# 1           1     Kansas   2892987  11.644342105263148%   75.95828947368425%
# 2           2   Kentucky   4397353   3.222993688007212%    85.2307484220019%
# 3           3  Louisiana   4625253   4.866489361702128%  54.978546099290796%
# 4           4      Maine   1329100  1.4319088319088318%   93.70740740740736%
# 5           5   Maryland   5930538    8.47249820014399%     52.679049676026%
#
#                  Black                Native                Asian  \
# 0  3.2569866342648868%   0.2897934386391251%   1.699392466585662%
# 1     6.5678947368421%   0.7339473684210529%   2.331052631578946%
# 2   8.272317403065832%   0.1666366095581602%  1.1298467087466182%
# 3   36.32624113475175%  0.48430851063829816%   1.669060283687941%
# 4  1.1344729344729356%   0.7883190883190888%  0.9658119658119669%
# ...

# %%
data = state3[['State', 'Income', 'GenderPop']]
data
# Out:
#        State               Income          GenderPop
# 0       Iowa   $53017.75304136253  1534595M_1558931F
# 1     Kansas  $53885.612648221344  1439862M_1453125F
# 2   Kentucky   $45285.80253623189  2164208M_2233145F
# 3  Louisiana   $44957.99376114082  2261156M_2364097F
# 4      Maine   $49181.97435897436    650081M_679019F
# 5   Maryland   $78765.40072463769         2872643M_F

# %%
state3.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      6 non-null      object
#  1   Income     6 non-null      object
#  2   GenderPop  6 non-null      object
# dtypes: object(3)
# memory usage: 136.0+ bytes

# %%
us_censes = pd.concat([state0,state1,state2,state3,state4,state5,state6,state7,state8,state9], ignore_index=True)

# %%
us_censes.to_csv('us_censes.csv', index=False)
us_censes.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_
